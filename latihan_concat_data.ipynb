# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import semua file csv per bulan Quater pertama tahun 2018 ke dataframe

df_jan = pd.read_csv(r"C:\Users\User\Documents\project_data\SampleData\2018\orderdata_Jan_2018.csv")

df_feb = pd.read_csv(r"C:\Users\User\Documents\project_data\SampleData\2018\orderdata_Feb_2018.csv")

df_mar = pd.read_csv(r"C:\Users\User\Documents\project_data\SampleData\2018\orderdata_Mar_2018.csv")

# %%
df = pd.concat([df_jan, df_feb, df_mar])

# %%
df
# Out:
#       id Tanggal_Order Waktu_Pesan       Nama_Pemesan     No_Resi  \
# 0      1    2018/01/15    19:56:05       Karla Nissle  60512-6443
# 1      2    2018/01/05    17:50:33        Galen Janic   49349-424
# 2      3    2018/01/13    20:52:39       Emma Beddoes  55926-0020
# 3      4    2018/01/27     4:52:12        Alane Morat  60681-2104
# 4      5    2018/01/04    18:50:42      Eugenie Jewis   63739-110
# ..   ...           ...         ...                ...         ...
# 895  896    2018/03/08     2:25:01    Romonda Billion   0378-7155
# 896  897    2018/03/17    13:54:12  Christian Dulinty   52959-978
# 897  898    2018/03/10    19:05:51        Arlie Braim  64725-1487
# 898  899    2018/03/21     4:35:53    Naoma Woodyeare   49230-209
# 899  900    2018/03/10     4:38:57        Nesta Klehn   66472-025
#
#                 Produk  Kategori  Jumlah_Pesanan  Harga  Diskon  Total_Harga  \
# 0              T-Shirt       NaN             9.0    NaN     NaN          NaN
# ...

# %%
# Sekalian latihan exporting data

df.to_csv('hasil latihan eksport dataframe.csv')
