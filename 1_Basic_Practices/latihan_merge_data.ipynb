# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt

# load dataset nya
df_order = pd.read_csv(r"C:\Users\User\Documents\project_data\SampleData\orderdata_clean.csv", sep=";")

df_customer = pd.read_csv(r"C:\Users\User\Documents\project_data\SampleData\customerdata.csv", sep=";")

# %%
df_order
# Out:
#       order_id tanggal_order Waktu_Pesan  User_id     No_Resi product_id  \
# 0       odr001    2018-01-15    19:56:05  user630  60512-6443   prod_007
# 1       odr003    2018-01-13    20:52:39  user910  55926-0020   prod_003
# 2       odr006    2018-01-20    04:00:42  user575   75921-158   prod_003
# 3       odr009    2018-01-28    20:25:52  user611   63304-637   prod_007
# 4       odr010    2018-01-24    11:30:07  user693   0013-2646   prod_001
# ...        ...           ...         ...      ...         ...        ...
# 18219  odr9995    2019-04-06    20:48:13  user929  48951-6056   prod_005
# 18220  odr9996    2019-04-22    00:32:46  user423   43063-172   prod_005
# 18221  odr9997    2019-04-23    02:19:22  user783   41250-829   prod_007
# 18222  odr9998    2019-04-26    18:53:50  user170   46994-458   prod_003
# 18223  odr9999    2019-04-19    18:25:46  user981   16571-441   prod_004
#
#        Jumlah_Pesanan  Diskon  Total_Harga    Profit        Kota  \
# ...

# %%
df_customer
# Out:
#        User_id Tanggal_Registrasi Waktu_Registrasi            Nama_Customer  \
# 0      user001         2023-04-02            04:17            Nama Customer
# 1      user002         2024-01-18            22:33             Lissa Gabala
# 2      user003         2023-07-15            23:44  Helenelizabeth Brewster
# 3      user004         2023-07-31            09:18      Haskell Van Arsdale
# 4      user005         2023-06-27            13:40          Mohammed Brewse
# ...        ...                ...              ...                      ...
# 1709  user1750         2019-04-29            10:34       Cordelie O' Timony
# 1710  user1751         2019-04-27            13:32             Alfie Billin
# 1711  user1752         2019-04-06            17:22           Hilliard Paute
# 1712  user1753         2019-04-29            03:39      Claudelle MacDirmid
# 1713  user1754         2019-04-06            09:40                Kym Grece
#
# ...

# %%
df_order.merge(df_customer, on='User_id')

# dalam paramter on adalah key kolom, harus persis sama di kedua table
# Out:
#        order_id tanggal_order Waktu_Pesan  User_id     No_Resi product_id  \
# 0        odr001    2018-01-15    19:56:05  user630  60512-6443   prod_007
# 1      odr11986    2019-08-30    20:20:29  user630  48951-4063   prod_005
# 2      odr12134    2019-08-28    07:36:23  user630   41520-434   prod_007
# 3      odr12307    2019-09-21    02:07:25  user630   41250-177   prod_007
# 4      odr12795    2019-10-01    17:33:33  user630  60505-6025   prod_005
# ...         ...           ...         ...      ...         ...        ...
# 18219   odr5193    2018-09-17    14:38:23  user142   49999-223   prod_005
# 18220   odr6382    2018-11-03    07:06:01  user142   42549-558   prod_003
# 18221   odr7597    2019-01-14    11:06:48  user142  57520-0392   prod_003
# 18222   odr8907    2019-03-28    12:37:44  user142  50025-1001   prod_007
# 18223   odr9796    2019-04-06    20:17:34  user142   21695-924   prod_002
#
#        Jumlah_Pesanan  Diskon  Total_Harga    Profit  ... Tanggal_Registrasi  \
# ...
