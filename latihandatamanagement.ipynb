# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt

# load dataset nya
df = pd.read_csv(r"C:\Users\User\Documents\project_data\SampleData\data_jobs.csv")

# Data cleaning bagian tanggal, lebih ke ngubah format aja sih
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# menggunakan fungsi sample dari pandas untuk mengambil sample data dari object

df.sample()
# Out:
#        job_title_short               job_title job_location  \
# 419456   Data Engineer  Contract Data Engineer    Leeds, UK
#
#                      job_via job_schedule_type  job_work_from_home  \
# 419456  via Big Country Jobs        Contractor               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 419456  United Kingdom 2023-01-04 01:43:43                   True
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 419456                 False  United Kingdom         NaN              NaN
#
#         salary_hour_avg                   company_name  \
# 419456              NaN  Fruition IT Resources Limited
#
#                                                job_skills  \
# 419456  ['sql', 'python', 'azure', 'aws', 'gcp', 'pysp...
#
#                                           job_type_skills
# 419456  {'cloud': ['azure', 'aws', 'gcp'], 'libraries'...

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 778234  Senior Data Scientist
# 168301          Data Engineer
# 432980         Data Scientist
# 61892            Data Analyst
# 318082  Senior Data Scientist
# 597551   Senior Data Engineer
# 345704           Data Analyst
# 618463          Data Engineer
# 508327   Senior Data Engineer
# 281791         Cloud Engineer
#
#                                                 job_title  \
# 778234                              Senior Data Scientist
# 168301  Advanced Data Engineer ( Alation) - Hybrid in ...
# 432980                             TS/ SCI Data Scientist
# 61892                      Business Intelligence Engineer
# 318082             Senior Business Intelligence Developer
# 597551                               Senior Data Engineer
# 345704                             Technical Data Analyst
# 618463            Sr. Data Engineer - Test Automation(QA)
# 508327                      Senior Data Engineer (Remote)
# ...

# %%
# biar sample gak berubah2
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
# menggunakan fungsi copy() dari pandas
# fungsinya untuk mengcopy dataframe
# berbeda dengan altered, contohnya df_alter = df_ asli .. ini hanya menambahkan alias karena memiliki key/id yang sama
# jadi kedua df ini akan ikut terubah-ubah, sedang fungsi copy() akan membuat key/id yang berbeda sehingga tidak akan mengubah df asli

df_baru = df.copy()

# %%
print('id df :', id(df))
print('id df_baru :', id(df_baru))
# Out:
# id df : 1662685533840
# id df_baru : 1662701166544
