# %% [markdown]
# ### Testing Basic Jupyter Notebook

# %%
print("Kumaha damang?")
# Out:
# Kumaha damang?

# %% [markdown]
# # Heading 1

# %% [markdown]
# Jadi ya beginilah penggunaan vs code pertama, masih membiasakan diri dengan environment, but i think its pretty cool and fast performance.

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %%
a = 1
while a < 10:
    print("I kill you")
    a += 1
# Out:
# I kill you
# I kill you
# I kill you
# I kill you
# I kill you
# I kill you
# I kill you
# I kill you
# I kill you

# %%
print("kumaha damang?")
# Out:
# kumaha damang?

# %% [markdown]
# ### Testing Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r'E:\UPGRADE SKILL\DATA ANALYTICS\DATA DUMMY\Data Order\Process\DATA ORDER - CLEAN.csv', sep=';')

# %%
df
# Out:
#       Tanggal Order Waktu Pesan          Nama Pemesan         Produk  \
# 0        14/07/2023    14:12:00       Lulita Roycroft        Sweater
# 1        26/07/2023    14:24:00           Eustace Gay           Topi
# 2        16/07/2023    14:38:00           Lanni Upson    Cargo Pants
# 3        31/12/2023    11:40:00           Kit Danniel    Cargo Pants
# 4        17/02/2023    07:11:00        Wallie Lorrain        T-Shirt
# ...             ...         ...                   ...            ...
# 10633    21/06/2023    17:52:00      Gerianne MacKean        Sweater
# 10634    28/02/2023    04:25:00           Bren Corkel  Parka Jackets
# 10635    06/07/2023    21:06:00  Kenyon Nunes Nabarro            Mug
# 10636    14/12/2023    18:11:00          Bern Hollows           Topi
# 10637    16/11/2023    06:14:00        Rockey Fiennes        Sweater
#
#         Kategori  Jumlah Pesanan   Harga  Diskon  Jumlah Harga  \
# 0        Jackets              74  125000       0       9250000
# ...

# %% [markdown]
# # Basic Python

# %% [markdown]
# ### Variables

# %%
base_salary = 1000000
bonus_rate = .10

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 1100000.0

# %% [markdown]
# ### Object
# To see object use type()

# %%
a = 25
b = "Marsupilami"
c = False
d = .25

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# bool

# %%
type(d)
# Out:
# float

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
# function is reusable piece of code that perform specific task
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
def halo():
    return "Selamat Datang"

# %%
halo()
# Out:
# 'Selamat Datang'

# %%
title = "Dragon Slayer"
location = "Hogwarts"
kill = 999

# %%
def display_info(title, location, kill):
    return print(f"Job :    {title}\nLocation:  {location}\nKill count:    {kill}")

# %%
display_info(title, location, kill)
# Out:
# Job :    Dragon Slayer
# Location:  Hogwarts
# Kill count:    999

# %% [markdown]
# ### Classes : The Template of Objects

# %%
class jobreq:
    def __init__(self, title, location, kill):
        self.title = title
        self.location = location
        self.kill = kill

# %% [markdown]
# ### Attributes : The variables of an object

# %%
job_1 = jobreq(title, location, kill)

# %%
job_1.title
# Out:
# 'Dragon Slayer'

# %% [markdown]
# ### Methods : The Functions of an Object

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
tulisan = "aku cinta data"

# %%
tulisan.upper()
# Out:
# 'AKU CINTA DATA'

# %%
tulisan.lower()
# Out:
# 'aku cinta data'

# %% [markdown]
# ### Data Types

# %% [markdown]
# - String
# - Booelan
# - Int
# - Float
# - Set
# - Etc

# %%
ini_var = "Aku Suka Data"

# %%
ini_var.split(sep=" ", maxsplit=2)
# Out:
# ['Aku', 'Suka', 'Data']

# %% [markdown]
# ### Magic Methods

# %% [markdown]
# ### Conditions

# %%
# If conditions

job_skill = 'SQL'
applicant_skill = 'SQL'
experience_years = 2

# %%
if job_skill == applicant_skill and experience_years >= 5:
    print('Skill and experience is match!')
elif experience_years >= 5:
    print('Enough experience, but skill not match')
elif job_skill == applicant_skill:
    print('skills match!')
else:
    print('No SQL skill and not enough experience')
# Out:
# skills match!

# %% [markdown]
# ### List

# %%
job_skills = ['SQL', 'Excel', 'Python']

# %%
job_skills.append('Tableau')

job_skills
# Out:
# ['SQL', 'Excel', 'Python', 'Tableau']

# %%
job_skills.remove('Excel')

job_skills
# Out:
# ['SQL', 'Python', 'Tableau']

# %%
len('Tableau')
# Out:
# 7

# %%
len(job_skills)
# Out:
# 3

# %%
job_skills[1]
# Out:
# 'Python'

# %%
job_skills[0]
# Out:
# 'SQL'

# %% [markdown]
# **List** : For a collection ordered item
# **Dict** : for key value pairs
# **set** : for unique items
# **tuple** : for fixed data

# %%
Tahun_Pengalaman = {
    'Orang_1': 11,
    'Orang_2': 15,
    'Orang_3': 6,
    'Orang_4': 27,
    'Orang_5': 4,
    'Orang_6': 8,
    'Orang_7': 4,
    'Orang_8': 27,
    'Orang_9': 2,
    'Orang_10': 19,
    'Orang_11': 2,
    'Orang_12': 7,
    'Orang_13': 9,
    'Orang_14': 15,
    'Orang_15': 9,
    'Orang_16': 20,
    'Orang_17': 25,
    'Orang_18': 14,
    'Orang_19': 20,
    'Orang_20': 30,
    'Orang_21': 5,
    'Orang_22': 7,
    'Orang_23': 16,
    'Orang_24': 25,
    'Orang_25': 20
}

# %%
for person in Tahun_Pengalaman:
    print(person)
# Out:
# Orang_1
# Orang_2
# Orang_3
# Orang_4
# Orang_5
# Orang_6
# Orang_7
# Orang_8
# Orang_9
# Orang_10
# Orang_11
# Orang_12
# Orang_13
# Orang_14
# Orang_15
# Orang_16
# Orang_17
# Orang_18
# Orang_19
# Orang_20
# Orang_21
# Orang_22
# Orang_23
# Orang_24
# Orang_25

# %%
for tahun in Tahun_Pengalaman.values():
    print(tahun)
# Out:
# 11
# 15
# 6
# 27
# 4
# 8
# 4
# 27
# 2
# 19
# 2
# 7
# 9
# 15
# 9
# 20
# 25
# 14
# 20
# 30
# 5
# 7
# 16
# 25
# 20

# %%
for key, value in Tahun_Pengalaman.items():
    if value > 20:
        print(value)
# Out:
# 27
# 27
# 25
# 30
# 25

# %% [markdown]
# ### PANDAS

# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\User\Documents\project_data\SampleData\sample_karyawan.xlsx')
# Out:
#     unique_id   nomor_identitas                     nama  \
# 0          10  4716834641345900                     Abhi
# 1          30  4716834641345900                     Abbi
# 2          53  4716866427869500                      Adi
# 3          72  4716866427869500                      Ady
# 4          81  4716534685463900  Bahuwirya Rajasa Jefri
# 5          88  4485738208448950             Atmaja Halim
# 6         122  4412854937087760   Ani Ida Mandasari S.IP
# 7         127  4412854548087760   Ani Ida Mandasari S.IP
# 8         132  4716534685463900   Bahuwirya Jefri Rajasa
# 9         138  4716834641345900                      Abi
# 10        139  4716534685463900   Bahuwirya Jefri Rajasa
# 11        148  4716534685463900   Bahuwirya Jefri Rajasa
# 12        151  4716934641345900                      Abi
# 13        152  4485738208448950             Halim Atmaja
# 14        158  4412854937087760   Ani Ida Mandasari S.IP
# ...

# %%
pd.read_excel(r'C:\Users\User\Documents\project_data\SampleData\sample_outlet.xlsx')
# Out:
#     unique_id  kode_outlet           nama_outlet  \
# 0           1   OUT0001256        EL DUA SEPULUH
# 1           2   OUT0001256            Inul Vizta
# 2           3   OUT0001258        EL DUA SEPULUH
# 3           4   OUT0001264       Happy Puppy Dog
# 4           5   OUT0001302            Inul Vizta
# 5           6   OUT0001303   INDMARCO PRISMATAMA
# 6           7   OUT0001306          DIVA LESTARI
# 7           8   OUT0001307      DIVA LESTARI, PT
# 8           9      OUT0002  INDOMARCO PRISMATAMA
# 9          10      OUT0003      DIVA LESTARI, PT
# 10         11      OUT0004      DIVA LESTARI, PT
# 11         12      OUT0009          DIVA LESTARI
# 12         13      OUT0010           Happy Puppy
# 13         14      OUT0016            Inul Vizta
# 14         15      OUT0020      DIVA LESTARI, PT
# 15         16   OUT0401842      DIVA LESTARI, PT
# 16         17   OUT0401843        EL DUA SEPULUH
# 17         18   OUT0401844           Happy Puppy
# ...

# %%
pd.read_excel(r'C:\Users\User\Documents\project_data\SampleData\sample_pelanggan.xlsx')
# Out:
#     unique_id                        nama   nomor_identitas  \
# 0           1          Sari Hastuti S.Psi  4024006192275820
# 1           2               Umaya Waskita  4024007105085230
# 2           3                Umay Waskita  4024007105085230
# 3           4                   Umaya Was  4024007105085230
# 4           5               Umaya Waskita  4024007105085230
# 5           6               Umaya Waskita  4024007105085230
# 6           7               Umaya Waskita  4024307105085230
# 7           8               Umaya Waskito  4024007105085230
# 8           9               Zyzy Yulianti  4024007107685700
# 9          10               Zizi Yulianti  4024007107685700
# 10         11               Zizi Yulianty  4024007107685700
# 11         12                      Zizi Y  4024007107685700
# 12         13     Paulin T Yuliarti S.Psi  4024007111906230
# 13         14  Paulin Tami Yuliarti S.Psi  4024007111906230
# 14         15        Paulin Tami Yuliarti  4024007111906230
#
# ...

# %%
df = pd.read_excel(r'SampleData/netflix_titles.xlsx')

# %%
df
# Out:
#      duration_minutes duration_seasons     type  \
# 0                  90              NaN    Movie
# 1                  94              NaN    Movie
# 2                 NaN                1  TV Show
# 3                 NaN                1  TV Show
# 4                  99              NaN    Movie
# ...               ...              ...      ...
# 6231              NaN               13  TV Show
# 6232              NaN                4  TV Show
# 6233               60              NaN    Movie
# 6234              NaN                2  TV Show
# 6235              NaN               10  TV Show
#
#                                             title           date_added  \
# 0         Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1                      Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2                              Transformers Prime  2018-09-08 00:00:00
# 3                Transformers: Robots in Disguise  2018-09-08 00:00:00
# ...

# %%
df['type']
# Out:
# 0         Movie
# 1         Movie
# 2       TV Show
# 3       TV Show
# 4         Movie
#          ...
# 6231    TV Show
# 6232    TV Show
# 6233      Movie
# 6234    TV Show
# 6235    TV Show
# Name: type, Length: 6236, dtype: object

# %%
df = pd.read_csv(r'C:\Users\User\Documents\project_data\SampleData\data_jobs.csv')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_title_short']
# Out:
# 0         Senior Data Engineer
# 1                 Data Analyst
# 2                Data Engineer
# 3                Data Engineer
# 4                Data Engineer
#                   ...
# 785736       Software Engineer
# 785737            Data Analyst
# 785738        Business Analyst
# 785739           Data Engineer
# 785740       Software Engineer
# Name: job_title_short, Length: 785741, dtype: object

# %%
df[['job_title_short', 'job_location']]
# Out:
#              job_title_short                         job_location
# 0       Senior Data Engineer                        Watertown, CT
# 1               Data Analyst         Guadalajara, Jalisco, Mexico
# 2              Data Engineer                      Berlin, Germany
# 3              Data Engineer                      San Antonio, TX
# 4              Data Engineer                       Washington, DC
# ...                      ...                                  ...
# 785736     Software Engineer                            Singapura
# 785737          Data Analyst                   Bad Rodach, Jerman
# 785738      Business Analyst                             Malaysia
# 785739         Data Engineer  Newark, New Jersey, Amerika Serikat
# 785740     Software Engineer                                India
#
# [785741 rows x 2 columns]

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg > 100000)]
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %% [markdown]
# ### Data Cleaning and Modification

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df['job_posted_date']
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df['Job_posted_month'] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sort_values('job_posted_date', inplace=True)

# %%
df.head()
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# ...

# %%
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...
